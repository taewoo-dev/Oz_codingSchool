# %% [markdown]
# 컴퓨터 기초 지식을 의미하는 CS(Computer science)는<br>
# 코딩 테스트와 함께 기술 면접에서 지원자에게 필수적으로 요구합니다.<br>
#
# 수업 내용 중 기술 면접에 자주 나오는 질문 3가지와 기본적으로 알아야 할 내용 과제로 선정했습니다.<br>
#
# 관련 내용에 대해서는 구글링 또는 관련 서적을 통해 상세히 공부하시고<br>
# 답변은 최대한 핵심만 담아 간결하게 작성해주세요<br>
#
# 기술 블로그를 운영 중이신 경우<br>
# 답변 내용을 기술 블로그에 작성하신 후 링크를 답변에 남겨주셔도 됩니다.<br>

# %% [markdown]
# -----

# %% [markdown]
# [문제1]
#
# Python의 변수 할당 개념을 다른 언어와 비교해 설명해주세요

# %% [markdown]
# python은 다른 언어와 다르게 자료형을 정하지 않으며 변수 선언과 할당을 동시에 한다. python의 변수 할당은 생성된 객체의 위치를 참조하는 것이다.
# 생성된 객체들은 heap영역에 생성되며 가비지콜렉터에 의해 관리된다
#
# c언어의 경우 변수를 할당 시 자료형을 정한다. 기본적으로는 stack영역에 할당되며 메모리의 동적할당을 원하는 경우 malloc 문법을 사용하여 heap영역에 데이터를 담을 수 있다.

# %% [markdown]
# ---

# %% [markdown]
# [문제2]
#
# Python의 실수형(float) 계산 시 오차가 발생하는 이유에 대해 간단히 설명해 주세요

# %%
컴퓨터에서 실수의 경우 유리수 + 무리수의 값을 비트로 표현하기에 매우 어려워 근사값을 이용하기 때문에 문제가 발생한다
0.3이 0.3이 아니라 0.3000000000004 와 같은 수로 저장되기 때문에 등호를 사용하기는 어렵다
또 반올림의 형식이 익숙한 방식인 사사오입(5가 앞자리에 상관없이 올림) 방식이 아니라 오사오입(5가 앞자리가 짝수일시 내림, 홀수일시 올림) 방식을 사용한다.

# %% [markdown]
# ----

# %% [markdown]
# [문제3]
#
# 슬라이싱에 대해 간단히 설명해주세요

# %%
시퀀스 객체들의 범위를 지정해서 원하는 영역만 가져오는 방법을 의미한다
