# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```변수 퀴즈에 들어있는 정답 "어중이떠중이"를 출력하기 위한 슬라이싱으로 올바른 것을 모두 골라주세요```
#
# 퀴즈 = "스님이 공중에 뜬다를 4글자로 말하면? 어중이떠중이"
#
# 1. print(퀴즈[21:27])
# 2. print(퀴즈[21:])
# 3. print(퀴즈[21:28])
# 4. print(퀴즈[28])

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 정답 : 3번

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```과일 변수에 들어있는 p의 개수를 구하는 코드로 올바른 것을 골라주세요```
#
# 과일 = "apple"
#
# 1. 과일.count('p')
# 2. count(과일, 'p')
# 3. 과일.index('p')
# 4. count('p')

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 정답 : 1번 count는 매서드로 단독으로 사용할 수 없다

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```참 또는 거짓으로 분류되지 않는 값을 골라주세요```
#
# 1. true
# 2. True
# 3. False
# 4. 0
# 5. 1

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 정답 : 1번 파이썬에서 참을 나타내는 값은 True이다 true는 틀렸음

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# ```문자열의 길이를 구하는 방법으로 올바른 것을 고르세요```
#
# 라라랜드 =  "사람들은 다른 사람들의 열정에 끌리게 되어있어 자신이 잊은 걸 상기시켜 주니까"
#
# 1. 라라랜드.len()
# 2. length(라라랜드)
# 3. len(라라랜드)
# 4. count(라라랜드)

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 정답 : 3번 len()은 파이썬 내장함수로 요소의 갯수를 반환한다

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```우영우 변수에 출력 값이 반대로 나오게 코드를 작성해주세요```
#
# 우영우 = "기러기토마토스위스역삼역"
#
# 출력값 : 역삼역스위스토마토기러기

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# print(우영우[::-1])
